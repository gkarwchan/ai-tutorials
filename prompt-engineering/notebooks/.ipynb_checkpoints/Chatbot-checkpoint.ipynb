# %%
from openai import OpenAI
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv()
client = OpenAI()

def get_completion(prompt, model ="gpt-3.5-turbo"):
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "user", "content": prompt}
        ],
        temperature=0,
    )
    return response.choices[0].message.content

# %%
def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    response = client.chat.completions.create(
        model = model,
        messages = messages,
        temperature = temperature,
    )
    return response.choices[0].message.content

# %%
messages =  [  
{'role':'system', 'content':'You are an assistant that speaks like Shakespeare.'},    
{'role':'user', 'content':'tell me a joke'},   
{'role':'assistant', 'content':'Why did the chicken cross the road'},   
{'role':'user', 'content':'I don\'t know'}  ]

# %%
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# To get to the other side where thou may find more laughs and japes!

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},    
{'role':'user', 'content':'Yes,  can you remind me, What is my name?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# I'm sorry, but I don't have information about your name. You can tell me your name, and I'll be happy to use it.

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},
{'role':'user', 'content':'Hi, my name is Isa'},
{'role':'assistant', 'content': "Hi Isa! It's nice to meet you. \
Is there anything I can help you with today?"},
{'role':'user', 'content':'Yes, you can remind me, What is my name?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Your name is Isa.

# %% [markdown]
# ## OrderBot

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, style={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display 

context = [ {'role':'system', 'content':"""
You are OrderBot, an automated service to collect orders for a pizza restaurant. \
You first greet the customer, then collects the order, \
and then asks if it's a pickup or delivery. \
You wait to collect the entire order, then summarize it and check for a final \
time if the customer wants to add anything else. \
If it's a delivery, you ask for an address. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very conversational friendly style. \
The menu includes \
pepperoni pizza  12.95, 10.00, 7.00 \
cheese pizza   10.95, 9.25, 6.50 \
eggplant pizza   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
greek salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
sausage 3.00 \
canadian bacon 3.50 \
AI sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
bottled water 5.00 \
"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='41bb1eb9-cdd4-4f2b-b5e6-e3c2f20435d6'>
#   <div id="c8da8e99-ed9d-4dd7-b3bb-25b09a5e788f" data-root-id="41bb1eb9-cdd4-4f2b-b5e6-e3c2f20435d6" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"5c1bdf4f-5d7d-4a20-bbe4-9aa9df73ac49":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"41bb1eb9-cdd4-4f2b-b5e6-e3c2f20435d6"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"a26ad0e7-22a3-425f-850b-cf4d631ee168","attributes":{"plot_id":"41bb1eb9-cdd4-4f2b-b5e6-e3c2f20435d6","comm_id":"09661fa5d4ae40c1a9f02ade5d993b66","client_comm_id":"929fabeafd5b4a2da02fcaf0385416bc"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"5c1bdf4f-5d7d-4a20-bbe4-9aa9df73ac49","roots":{"41bb1eb9-cdd4-4f2b-b5e6-e3c2f20435d6":"c8da8e99-ed9d-4dd7-b3bb-25b09a5e788f"},"root_ids":["41bb1eb9-cdd4-4f2b-b5e6-e3c2f20435d6"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 45
#      38 button_conversation = pn.widgets.Button(name="Chat!")
#      40 interactive_conversation = pn.bind(collect_messages, button_conversation)
#      42 dashboard = pn.Column(
#      43     inp,
#      44     pn.Row(button_conversation),
# ---> 45     pn.panel(interactive_conversation, loading_indicator=True, height=300),
#      46 )
#      48 dashboard
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/panel/pane/base.py:87, in panel(obj, **kwargs)
#      85 if kwargs.get('name', False) is None:
#      86     kwargs.pop('name')
# ---> 87 pane = PaneBase.get_pane_type(obj, **kwargs)(obj, **kwargs)
#      88 if len(pane.layout) == 1 and pane._unpack:
#      89     return pane.layout[0]
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/panel/param.py:836, in ParamRef.__init__(self, object, **params)
#     834 self._validate_object()
#     835 if not self.defer_load:
# --> 836     self._replace_pane()
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/panel/param.py:904, in ParamRef._replace_pane(self, force, *args)
#     902 else:
#     903     try:
# --> 904         new_object = self.eval(self.object)
#     905         if new_object is Skip and new_object is Undefined:
#     906             self._inner_layout.loading = False
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/panel/param.py:1119, in ParamFunction.eval(self, ref)
#    1117 @classmethod
#    1118 def eval(self, ref):
# -> 1119     return eval_function_with_deps(ref)
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/param/parameterized.py:163, in eval_function_with_deps(function)
#     161         args = (getattr(dep.owner, dep.name) for dep in arg_deps)
#     162         kwargs = {n: getattr(dep.owner, dep.name) for n, dep in kw_deps.items()}
# --> 163 return function(*args, **kwargs)
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/param/depends.py:85, in depends.<locals>._depends(*args, **kw)
#      83 @wraps(func)
#      84 def _depends(*args, **kw):
# ---> 85     return func(*args, **kw)
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/param/reactive.py:598, in bind.<locals>.wrapped(*wargs, **wkwargs)
#     595 @depends(**dependencies, watch=watch)
#     596 def wrapped(*wargs, **wkwargs):
#     597     combined_args, combined_kwargs = combine_arguments(wargs, wkwargs)
# --> 598     return eval_fn()(*combined_args, **combined_kwargs)
#
# Cell In[10], line 10, in collect_messages(_)
#       6 context.append({'role':'assistant', 'content':f"{response}"})
#       7 panels.append(
#       8     pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
#       9 panels.append(
# ---> 10     pn.Row('Assistant:', pn.pane.Markdown(response, width=600, style={'background-color': '#F6F6F6'})))
#      12 return pn.Column(*panels)
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/panel/pane/base.py:311, in Pane.__init__(self, object, **params)
#     310 def __init__(self, object=None, **params):
# --> 311     super().__init__(object=object, **params)
#     312     self._internal_callbacks.append(
#     313         self.param.watch(self._update_pane, self._rerender_params)
#     314     )
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/panel/pane/base.py:155, in PaneBase.__init__(self, object, **params)
#     153 def __init__(self, object=None, **params):
#     154     self._object_changing = False
# --> 155     super().__init__(object=object, **params)
#     156     if not hasattr(self, '_internal_callbacks'):
#     157         self._internal_callbacks = []
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/panel/reactive.py:645, in Reactive.__init__(self, refs, **params)
#     643     if refs:
#     644         param.bind(self._sync_refs, *refs, watch=True)
# --> 645 super().__init__(**params)
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/panel/reactive.py:129, in Syncable.__init__(self, **params)
#     127 def __init__(self, **params):
#     128     self._themer = None
# --> 129     super().__init__(**params)
#     131     # Useful when updating model properties which trigger potentially
#     132     # recursive events
#     133     self._updating = False
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/panel/viewable.py:732, in Viewable.__init__(self, **params)
#     730 def __init__(self, **params):
#     731     hooks = params.pop('hooks', [])
# --> 732     super().__init__(**params)
#     733     self._hooks = hooks
#     735     if self.loading:
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/panel/viewable.py:563, in Renderable.__init__(self, **params)
#     561 self._comms = {}
#     562 self._kernels = {}
# --> 563 super().__init__(**params)
#     564 self._found_links = set()
#     565 self._logger = logging.getLogger(f'{__name__}.{type(self).__name__}')
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/panel/viewable.py:308, in Layoutable.__init__(self, **params)
#     306 if 'design' not in params and self.param.design.default is None:
#     307     params['design'] = config.design
# --> 308 super().__init__(**params)
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/param/parameterized.py:4325, in Parameterized.__init__(self, **params)
#    4323 if self.param.name.default == self.__class__.__name__:
#    4324     self.param._generate_name()
# -> 4325 refs, deps = self.param._setup_params(**params)
#    4326 object_count += 1
#    4328 self._param__private.initialized = True
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/param/parameterized.py:1697, in as_uninitialized.<locals>.override_initialization(self_, *args, **kw)
#    1695 original_initialized = parameterized_instance._param__private.initialized
#    1696 parameterized_instance._param__private.initialized = False
# -> 1697 ret = fn(self_, *args, **kw)
#    1698 parameterized_instance._param__private.initialized = original_initialized
#    1699 return ret
#
# File ~/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages/param/parameterized.py:1948, in Parameters._setup_params(self_, **params)
#    1946 desc = self_.cls.get_param_descriptor(name)[0] # pylint: disable-msg=E1101
#    1947 if not desc:
# -> 1948     raise TypeError(
#    1949         f"{self.__class__.__name__}.__init__() got an unexpected "
#    1950         f"keyword argument {name!r}"
#    1951     )
#    1953 pobj = objects.get(name)
#    1954 if pobj is None or not pobj.allow_refs:
#    1955     # Until Parameter.allow_refs=True by default we have to
#    1956     # speculatively evaluate a values to check whether they
#    1957     # contain a reference and warn the user that the
#    1958     # behavior may change in future.
#
# TypeError: Markdown.__init__() got an unexpected keyword argument 'style'

# %%
# !pip install panel
# Out:
# Collecting panel
#   Downloading panel-1.7.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: bleach in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from panel) (6.2.0)
# Collecting bokeh<3.8.0,>=3.5.0 (from panel)
#   Downloading bokeh-3.7.3-py3-none-any.whl.metadata (12 kB)
# Collecting linkify-it-py (from panel)
#   Downloading linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting markdown (from panel)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting markdown-it-py (from panel)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting mdit-py-plugins (from panel)
#   Downloading mdit_py_plugins-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: packaging in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from panel) (25.0)
# Collecting pandas>=1.2 (from panel)
#   Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting param<3.0,>=2.1.0 (from panel)
#   Downloading param-2.2.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting pyviz-comms>=2.0.0 (from panel)
#   Downloading pyviz_comms-3.0.4-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: requests in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from panel) (2.32.3)
# Requirement already satisfied: tqdm in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from panel) (4.67.1)
# Requirement already satisfied: typing-extensions in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from panel) (4.13.2)
# Requirement already satisfied: Jinja2>=2.9 in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from bokeh<3.8.0,>=3.5.0->panel) (3.1.6)
# Collecting contourpy>=1.2 (from bokeh<3.8.0,>=3.5.0->panel)
#   Using cached contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting narwhals>=1.13 (from bokeh<3.8.0,>=3.5.0->panel)
#   Downloading narwhals-1.41.0-py3-none-any.whl.metadata (11 kB)
# Collecting numpy>=1.16 (from bokeh<3.8.0,>=3.5.0->panel)
#   Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting pillow>=7.1.0 (from bokeh<3.8.0,>=3.5.0->panel)
#   Using cached pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: PyYAML>=3.10 in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from bokeh<3.8.0,>=3.5.0->panel) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from bokeh<3.8.0,>=3.5.0->panel) (6.5.1)
# Collecting xyzservices>=2021.09.1 (from bokeh<3.8.0,>=3.5.0->panel)
#   Downloading xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from Jinja2>=2.9->bokeh<3.8.0,>=3.5.0->panel) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from pandas>=1.2->panel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from pandas>=1.2->panel) (2025.2)
# Collecting tzdata>=2022.7 (from pandas>=1.2->panel)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.2->panel) (1.17.0)
# Requirement already satisfied: webencodings in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from bleach->panel) (0.5.1)
# Collecting uc-micro-py (from linkify-it-py->panel)
#   Downloading uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting mdurl~=0.1 (from markdown-it-py->panel)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from requests->panel) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from requests->panel) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from requests->panel) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ghass/miniconda3/envs/openai-lab-env/lib/python3.12/site-packages (from requests->panel) (2025.4.26)
# Downloading panel-1.7.1-py3-none-any.whl (29.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 29.6 MB/s eta 0:00:0000:0100:01
# Downloading bokeh-3.7.3-py3-none-any.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 30.5 MB/s eta 0:00:00a 0:00:01
# Downloading param-2.2.0-py3-none-any.whl (119 kB)
# Downloading contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Downloading narwhals-1.41.0-py3-none-any.whl (357 kB)
# Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
# Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 29.9 MB/s eta 0:00:00
# Downloading pyviz_comms-3.0.4-py3-none-any.whl (83 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Downloading linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading mdit_py_plugins-0.4.2-py3-none-any.whl (55 kB)
# Downloading uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Installing collected packages: xyzservices, uc-micro-py, tzdata, pillow, param, numpy, narwhals, mdurl, markdown, pyviz-comms, pandas, markdown-it-py, linkify-it-py, contourpy, mdit-py-plugins, bokeh, panel
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [panel]m16/17 [panel]wn-it-py]
# Successfully installed bokeh-3.7.3 contourpy-1.3.2 linkify-it-py-2.0.3 markdown-3.8 markdown-it-py-3.0.0 mdit-py-plugins-0.4.2 mdurl-0.1.2 narwhals-1.41.0 numpy-2.2.6 pandas-2.2.3 panel-1.7.1 param-2.2.0 pillow-11.2.1 pyviz-comms-3.0.4 tzdata-2025.2 uc-micro-py-1.0.3 xyzservices-2025.4.0

# %%
messages =  context.copy()
messages.append(
{'role':'system', 'content':'create a json summary of the previous food order. Itemize the price for each item\
 The fields should be 1) pizza, include size 2) list of toppings 3) list of drinks, include size   4) list of sides include size  5)total price '},    
)
 #The fields should be 1) pizza, price 2) list of toppings 3) list of drinks, include size include price  4) list of sides include size include price, 5)total price '},    

response = get_completion_from_messages(messages, temperature=0)
print(response)
# Out:
# {
#   "pizza": {
#     "type": "pepperoni pizza",
#     "size": "large"
#   },
#   "toppings": [
#     "extra cheese",
#     "mushrooms"
#   ],
#   "drinks": [
#     {
#       "type": "coke",
#       "size": "medium"
#     }
#   ],
#   "sides": [
#     {
#       "type": "fries",
#       "size": "regular"
#     }
#   ],
#   "total price": 23.45
# }
